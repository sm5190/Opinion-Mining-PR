# %%
# !pip install tweet-preprocessor
# !pip install contractions

# !pip install gensim
# Out:
# ...
#      |████████████████████████████████| 106 kB 7.1 MB/s
# ...
#      |████████████████████████████████| 284 kB 40.4 MB/s
# ...

# %%
from tensorflow import keras
model = keras.models.load_model('/content/drive/MyDrive/323 final/analysis data/model-010-0.910297.h5')

# %%
max_features = 11000
maxlen = 200

# %%
import preprocessor as p

import contractions as c
from bs4 import BeautifulSoup
from gensim.parsing.preprocessing import remove_stopwords
import numpy as np
import pandas as pd
from sklearn import feature_extraction, model_selection

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#"Israel war criminal stop funding crimes humanity US tax dollars !!"
input="i pussy not mysogynist not cringe red pill guy !!!!"

# %%
input=c.fix(input)
input=p.clean(input)

# %%
input = BeautifulSoup(input).get_text()

# %%
input
# Out:
# 'i pussy not mysogynist not cringe red pill guy !!!!'

# %%
import string
regular_punct = list(string.punctuation)
def remove_punctuation(line,punct_list):
    for punc in punct_list:
        if punc in line:
            line = line.replace(punc, ' ')
    return line.strip()

input=remove_punctuation(input,regular_punct)

# %%
tl=input.lower()

# %%
t=remove_stopwords(tl)

# %%
t=remove_stopwords(tl)

# %%
from tensorflow.keras import models, layers, preprocessing as kprocessing
from nltk.tokenize import word_tokenize,sent_tokenize
from bs4 import BeautifulSoup
import re,string,unicodedata
from keras.preprocessing import text, sequence

# %%
df=pd.read_csv('/content/drive/MyDrive/323 final/Online dataset/try_online_no_offensive_data.csv')
df.Text=df.Text.astype(str)

# %%
dtf_train, dtf_test = model_selection.train_test_split(df, test_size=0.3,random_state=42)

# %%
#tokenizer = text.Tokenizer(num_words=max_features)
tokenizer = text.Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(dtf_train['Text'])
#tokenized_train = tokenizer.texts_to_sequences(df['Text'])

# %%
t
# Out:
# 'pussy mysogynist cringe red pill guy'

# %%
 
corpus = [t]
## create list of n-grams
lst_corpus = []
for string in corpus:
    lst_words = string.split()
    lst_grams = [" ".join(lst_words[i:i+1]) for i in range(0, 
                 len(lst_words), 1)]
    lst_corpus.append(lst_grams)   
lst_text2seq = tokenizer.texts_to_sequences(lst_corpus)
## padding sequence
test = kprocessing.sequence.pad_sequences(lst_text2seq, maxlen=200)

# %%
test

# %%
 np.argmax(model.predict(test),axis=1)
# Out:
# array([0])

# %%
model.predict(test)
# Out:
# array([[9.0458506e-01, 2.8974595e-02, 6.5830082e-02, 6.1026018e-04]],
#       dtype=float32)
